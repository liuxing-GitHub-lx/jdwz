# %%
import time
from datetime import datetime

import pykeyboard
import pymouse
import pyautogui
import win32clipboard as w
import win32con
import pandas as pd

# %%
df = pd.read_csv('jdwz.csv', index_col=0)
df
# Out:
#           岗位代码   用人单位序号 用人单位名    称  岗位类别      岗位\r\n名称                从事工作  \
# 0   2023006577  D232156   陆军军事交通学院    高教            助教          航海技术相关课程教学
# 1   2023006578  D232156   陆军军事交通学院    高教            助教          航海技术相关课程教学
# 2   2023008244  D232206     海军潜艇学院    高教            助教          航海技术相关课程教学
# 3   2023008829  D232210     海军士官学校    高教            助教          航海技术相关课程教学
# 4   2023025363  D233386   武警部队海警学院    高教            助教          航海技术相关课程教学
# 5   2023025364  D233386   武警部队海警学院    高教            助教          航海技术相关课程教学
# 6   2023025365  D233386   武警部队海警学院    高教            助教          航海技术相关课程教学
# 7   2023025366  D233386   武警部队海警学院    高教            助教          航海技术相关课程教学
# 8   2023025373  D233386   武警部队海警学院    高教            助教          航海技术相关课程教学
# 9   2023025375  D233386   武警部队海警学院    高教            助教          航海技术相关课程教学
# 10  2023025565  D233388   武警部队士官学校    高教            助教          航海技术相关课程教学
# ...

# %%
idxList = df['岗位代码'].values
idxList
# Out:
# array([2023006577, 2023006578, 2023008244, 2023008829, 2023025363,
#        2023025364, 2023025365, 2023025366, 2023025373, 2023025375,
#        2023025565, 2023025566, 2023006535, 2023006553, 2023006580,
#        2023006581, 2023025567, 2023019027, 2023019034, 2023019043,
#        2023019045, 2023020001, 2023020002], dtype=int64)
